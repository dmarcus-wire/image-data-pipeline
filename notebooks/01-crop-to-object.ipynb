# %% [markdown]
# ## Import Packages

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %% [markdown]
# ## Function to display images in Jupyter Notebooks

# %%
# convert opencv BGR to RGB ordering
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %% [markdown]
# ## Pass the image to load

# %%
args = {
	"image": "../images/output/uss-freedom-original.jpg"
}

# %% [markdown]
# ## load the image and display

# %%
# load the input image and display it to our screen
image = cv2.imread(args["image"])
(h, w, c) = image.shape[:3]

# display the image dimensions
print("width: {} pixels".format(image.shape[1]))
print("heigth: {} pixels".format(image.shape[0]))
print("channels: {}".format(image.shape[2]))

plt_imshow("Original", image)
# Out:
# width: 2100 pixels
# heigth: 1400 pixels
# channels: 3

# %% [markdown]
# ## Crop to object

# %%
# cropping an image with OpenCV is accomplished via simple NumPy
# array slices in startY:endY, startX:endX order -- here we are
# cropping the face from the image
lcs = image[700:1050, 300:1400]

(h, w, c) = lcs.shape[:3]

# display the image dimensions
print("width: {} pixels".format(lcs.shape[1]))
print("heigth: {} pixels".format(lcs.shape[0]))
print("channels: {}".format(lcs.shape[2]))

plt_imshow("LCS", lcs)
cv2.imwrite("../images/output/uss-freedom-cropped.jpg", lcs)
# Out:
# width: 1100 pixels
# heigth: 350 pixels
# channels: 3
# True
